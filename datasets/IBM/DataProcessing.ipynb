# %%
import pandas as pd

# %%
df = pd.read_csv("../IBM/TN/TN_incoming_people_till_yesterday.csv").fillna(0)
df
# Out:
#             date            travel_mode  passengers  positive_cases
# 0     2020-07-23       airport_domestic      153963           468.0
# 1     2020-07-23  airport_international       41460           751.0
# 2     2020-07-23            grand total      420925          5044.0
# 3     2020-07-23               road_bus       40370             0.0
# 4     2020-07-23               road_own      159986          3367.0
# ...          ...                    ...         ...             ...
# 3579  2022-02-13            grand total     7720086          9281.0
# 3580  2022-02-13               road_bus       41416             0.0
# 3581  2022-02-13               road_own      357267          6517.0
# 3582  2022-02-13               sea_port        2447            34.0
# 3583  2022-02-13                  train       35374           428.0
#
# [3584 rows x 4 columns]

# %%
df2 = df.pivot( index="date", columns=["travel_mode"], values=["passengers", "positive_cases"])
df2
df2.to_csv("./TN_processed/TN_incoming_people_till_yesterday_transposed.csv")

# %%
df_rt = pd.read_csv("./TN/TN_case_info_with_rt.csv")
df_rt_2 = df_rt["I"]
len(df2[(    'passengers',      'airport_domestic')])
df_rt_2 = df_rt_2[:-1]
len(df_rt_2)
df2.insert(0, "Rt_mean", df_rt["I"][:-1], True)

# %%
df2[("passengers", "I")]=df_rt["I"][:-1]
# Out:
# C:\Users\mypc\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2895: PerformanceWarning: indexing past lexsort depth may impact performance.
#   return runner(coro)
# C:\Users\mypc\anaconda3\lib\site-packages\IPython\core\async_helpers.py:68: PerformanceWarning: indexing past lexsort depth may impact performance.
#   coro.send(None)

# %%
df2["passengers"]["I"]=df_rt["I"][:-1]
# Out:
# <ipython-input-64-9c923c5698f5>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["passengers"]["I"]=df_rt["I"][:-1]

# %%
df2
# Out:
#             Rt_mean           passengers                                    \
# travel_mode             airport_domestic airport_international grand total
# date
# 2020-07-23      NaN NaN         153963.0               41460.0    420925.0
# 2020-07-24      NaN NaN         157882.0               42090.0    427048.0
# 2020-07-25      NaN NaN         160892.0               42509.0    432041.0
# 2020-07-26      NaN NaN         165068.0               43276.0    439297.0
# 2020-07-28      NaN NaN         172063.0               44450.0    450096.0
# ...             ...  ..              ...                   ...         ...
# 2022-01-22      NaN NaN        6741859.0              651506.0   7833121.0
# 2022-01-23      NaN NaN        6751869.0              652640.0   7844475.0
# 2022-01-24      NaN NaN        6762028.0              653666.0   7855782.0
# 2022-01-25      NaN NaN        6772601.0              654500.0   7867326.0
# ...
