# %%
import pandas as pd

# %%
df = pd.read_csv("../datasets/TN/TN_case_info_with_rt.csv")

# %%
df[df.new_active_cases_today<0]
# Out:
#          date  testing_facilities  government_testing_facilities  \
# 8    01-08-20                 121                             59
# 10   03-08-20                 122                             59
# 11   04-08-20                 125                             60
# 12   05-08-20                 125                             60
# 13   06-08-20                 126                             61
# ..        ...                 ...                            ...
# 482  24-12-21                 318                             69
# 483  25-12-21                 318                             69
# 484  26-12-21                 318                             69
# 485  27-12-21                 318                             69
# 486  28-12-21                 318                             69
#
#      private_testing_facilities  active_cases_yesterday  \
# 8                            62                   57968
# 10                           63                   56998
# ...

# %%
df.describe()
# Out:
#        testing_facilities  government_testing_facilities  \
# count          513.000000                     513.000000
# mean           254.951267                      67.744639
# std             51.601496                       2.273122
# min            113.000000                      58.000000
# 25%            233.000000                      67.000000
# 50%            263.000000                      69.000000
# 75%            293.000000                      69.000000
# max            331.000000                      69.000000
#
#        private_testing_facilities  active_cases_yesterday  \
# count                  513.000000              513.000000
# mean                   187.206628            41744.645224
# std                     49.573298            59421.227351
# min                     55.000000             3952.000000
# 25%                    166.000000             9039.000000
# 50%                    194.000000            17322.000000
# ...

# %%
df.head()
# Out:
#        date  testing_facilities  government_testing_facilities  \
# 0  23-07-20                 113                             58
# 1  24-07-20                 114                             58
# 2  25-07-20                 115                             58
# 3  26-07-20                 116                             58
# 4  28-07-20                 119                             58
#
#    private_testing_facilities  active_cases_yesterday  positive_tested_cases  \
# 0                          55                   51765                   6472
# 1                          56                   52939                   6785
# 2                          57                   53132                   6988
# 3                          58                   52273                   6986
# 4                          61                   54896                   6972
#
#    discharged_patients  deaths_today  active_cases_today  \
# 0                 5210            88               52939
# ...

# %%
df2 = pd.read_csv("../datasets/final/tnfinal.csv")
df2
# Out:
#            Date       State  Confirmed  New Cases      T     H         Rt  \
# 0    15/03/2020  Tamil Nadu          1          0  31.27  63.0   5.000000
# 1    16/03/2020  Tamil Nadu          1          0  32.33  60.0   5.000000
# 2    17/03/2020  Tamil Nadu          1          0  32.00  62.0   5.000000
# 3    18/03/2020  Tamil Nadu          1          0  31.47  64.0   5.000000
# 4    19/03/2020  Tamil Nadu          2          1  32.60  58.0  10.000000
# ..          ...         ...        ...        ...    ...   ...        ...
# 287  27/12/2020  Tamil Nadu     813161       1019  27.60  68.0   0.935213
# 288  28/12/2020  Tamil Nadu     814170       1009  27.20  65.0   0.933976
# 289  29/12/2020  Tamil Nadu     815175       1005  27.53  70.0   0.938267
# 290  30/12/2020  Tamil Nadu     816132        957  28.13  75.0   0.938948
# 291  31/12/2020  Tamil Nadu     817077        945  28.07  68.0   0.935654
#
#       TJ  DI  CLE   GA   MT  ON
# 0      0   0    0    0    0   0
# ...

# %%
df2[df2.Date=='23/07/2020']
df2[df2.Date=='25/07/2020']
# Out:
#            Date       State  Confirmed  New Cases      T     H        Rt   TJ  \
# 132  25/07/2020  Tamil Nadu     199749       6785  32.87  64.0  1.200968  126
#
#      DI  CLE   GA   MT  ON
# 132   0   25  132  102   0

# %%
df3=df["positive_tested_cases"]

# %%
df3
# Out:
# 0       6472
# 1       6785
# 2       6988
# 3       6986
# 4       6972
#        ...
# 508    29870
# 509    30744
# 510    30580
# 511    30215
# 512    30055
# Name: positive_tested_cases, Length: 513, dtype: int64

# %%
df3.to_csv("../datasets/TN/TN_case_info_with_rt.csv",index=False, header=False)

# %%
df4=pd.read_csv("../datasets/TN/TN_case_info_with_rt.csv")
df4.head()
# Out:
#    6472
# 0  6785
# 1  6988
# 2  6986
# 3  6972
# 4  6426
